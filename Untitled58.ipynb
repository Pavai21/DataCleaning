# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("C:\\Users\\pavai\\Documents\\data_clean.xlsx")
df.head(5)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.drop('Temp C',axis=1,inplace=True)

# %%
df['Month']=pd.to_numeric(df['Month'], errors='coerce')

# %%
df['Weather']=df['Weather'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 9.0 KB

# %%
df.shape
# Out:
# (158, 8)

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (157, 8)

# %%
df.rename({'Solar.R':'Solar'},axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 10.1 KB

# %%
df.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
plt.hist(df['Ozone'])
# Out:
# (array([20., 31., 19., 52.,  5.,  8., 10.,  5.,  1.,  4.]),
#  array([  1. ,  13.1,  25.2,  37.3,  49.4,  61.5,  73.6,  85.7,  97.8,
#         109.9, 122. ]),
#  <a list of 10 Patch objects>)

# %%
plt.style.use('default')
df.boxplot(['Ozone'])

# %%
df[df.Ozone>125]
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 61   135.0  269.0   4.1    7.0    1  2010    84       S
# 116  168.0  238.0   3.4    8.0   25  2010    81      PS

# %%
df.drop([61,116],inplace=True)

# %%
Ozone=df['Ozone'].mean()
Ozone
# Out:
# 39.94017094017094

# %%
df['Ozone']=df['Ozone'].fillna(Ozone)

# %%
Solar = df['Solar'].mean()
Solar
# Out:
# 184.44594594594594

# %%
df['Solar']=df['Solar'].fillna(Solar)

# %%
Month=df['Month'].mean()
Month
# Out:
# 7.025974025974026

# %%
df['Month']=df['Month'].fillna(Month)

# %%
Weather=df['Weather'].mode()
Weather
# Out:
# 0    S
# Name: Weather, dtype: category
# Categories (3, object): [C, PS, S]

# %%
df['Weather']=df['Weather'].fillna(Weather)

# %%
df['Weather'].value_counts()
# Out:
# S     57
# C     49
# PS    46
# Name: Weather, dtype: int64

# %%
df['Weather'].value_counts().plot.bar()

# %%
sns.relplot(data=df,x='Month',y='Temp',hue='Weather',kind='line',height=4,aspect=2.5)

# %%
sns.relplot(data=df,x='Month',y='Ozone',kind='line',aspect=2.5)
